# %%
#Assignment 2 Ozone model
# install.packages("gclus")
library(gclus)
data(ozone)
# Out:
# Loading required package: cluster

# %%
head(ozone)
# Out:
#   Ozone Temp InvHt Pres Vis Hgt  Hum InvTmp Wind
# 1 3     40   2693  -25  250 5710 28  47.66  4
# 2 5     45    590  -24  100 5700 37  55.04  3
# 3 5     54   1450   25   60 5760 51  57.02  3
# 4 6     35   1568   15   60 5720 69  53.78  4
# 5 4     45   2631  -33  100 5790 19  54.14  6
# 6 4     55    554  -28  250 5790 25  64.76  3

# %%
## 1.
fit = glm(Ozone~., data=ozone)
anova(fit, test ="Chisq")
summary(fit)

options(repr.plot.width=10, repr.plot.height=10)
par(mfrow=c(2,2))
plot(fit)
hist(fit$residuals)
plot(fit$residuals, fit$fitted.values)

par(mfrow=c(2,4))
Rd = residuals(fit,type='deviance')
plot(ozone$Temp,Rd, xlab='Temp', ylab='Deviance residuals')
abline(ozone$Temp,Rd)
plot(ozone$InvHt,Rd, xlab='InvHt', ylab='Deviance residuals') # Residuals seem to have an inverse fan/ cone shape
plot(ozone$Pres,Rd, xlab='Pres', ylab='Deviance residuals')
plot(ozone$Vis,Rd, xlab='Vis', ylab='Deviance residuals') # Looks like there is a trend in the residuals
plot(ozone$Hgt,Rd, xlab='Hgt', ylab='Deviance residuals') # Residuals seem to fan out in a cone shape
plot(ozone$Hum,Rd, xlab='Hum', ylab='Deviance residuals')
plot(ozone$InvTmp,Rd, xlab='InvTmp', ylab='Deviance residuals')
plot(ozone$Wind,Rd, xlab='wind', ylab='Deviance residuals')
# Out:
#        Df Deviance     Resid. Df Resid. Dev Pr(>Chi)
# NULL   NA           NA 329       21115.406             NA
# Temp    1 12869.774874 328        8245.631  9.592562e-140
# InvHt   1   889.395530 327        7356.236   3.701928e-11
# Pres    1   224.022041 326        7132.214   8.995522e-04
# Vis     1   193.100428 325        6939.113   2.052379e-03
# Hgt     1    24.407660 324        6914.706   2.731114e-01
# Hum     1   314.104757 323        6600.601   8.442724e-05
# InvTmp  1    74.497861 322        6526.103   5.553689e-02
# Wind    1     2.776474 321        6523.326   7.116598e-01
# Call:
# glm(formula = Ozone ~ ., data = ozone)
#
# Deviance Residuals:
#      Min        1Q    Median        3Q       Max
# -12.8877   -3.1853   -0.2024    2.7414   13.4535
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) 24.5905063 28.8082951   0.854 0.393968
# Temp         0.2741422  0.0505439   5.424 1.15e-07 ***
# InvHt       -0.0005228  0.0002865  -1.825 0.068920 .
# Pres         0.0018811  0.0113364   0.166 0.868311
# Vis         -0.0064247  0.0037763  -1.701 0.089850 .
# Hgt         -0.0070765  0.0054566  -1.297 0.195611
# Hum          0.0706651  0.0188580   3.747 0.000212 ***
# InvTmp       0.1428511  0.0764538   1.868 0.062608 .
# Wind         0.0491905  0.1330810   0.370 0.711903
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for gaussian family taken to be 20.32189)
#
#     Null deviance: 21115.4  on 329  degrees of freedom
# Residual deviance:  6523.3  on 321  degrees of freedom
# AIC: 1941.2
#
# Number of Fisher Scoring iterations: 2
# Plot with title “”
# Plot with title “Histogram of fit$residuals”
# plot without title

# %%
options(repr.plot.width=10, repr.plot.height=5)
par(mfrow=c(2,4))
plot(ozone$Ozone~ozone$Temp, xlab='Ozone', ylab='Temp', main = "Ozone over Temp", col=c("green","blue"))
abline(lm(ozone$Ozone~ozone$Temp), col = "Red")

plot(ozone$Ozone~ozone$InvHt, xlab='Ozone', ylab='InvHt', main = "Ozone over InvHt", col=c("green","blue"))
abline(lm(ozone$Ozone~ozone$InvHt), col = "Red")

plot(ozone$Ozone~ozone$Pres, xlab='Ozone', ylab='Pres', main = "Ozone over Pres", col=c("green","blue"))
abline(lm(ozone$Ozone~ozone$Pres), col = "Red")

plot(ozone$Ozone~ozone$Vis, xlab='Ozone', ylab='Vis', main = "Ozone over Vis", col=c("green","blue"))
abline(lm(ozone$Ozone~ozone$Vis), col = "Red")

plot(ozone$Ozone~ozone$Hgt, xlab='Ozone', ylab='Hgt', main = "Ozone over Hgt", col=c("green","blue"))
abline(lm(ozone$Ozone~ozone$Hgt), col = "Red")

plot(ozone$Ozone~ozone$Hum, xlab='Ozone', ylab='Hum', main = "Ozone over Hum", col=c("green","blue"))
abline(lm(ozone$Ozone~ozone$Hum), col = "Red")

plot(ozone$Ozone~ozone$InvTmp, xlab='Ozone', ylab='InvTmp', main = "Ozone over InvTmp", col=c("green","blue"))
abline(lm(ozone$Ozone~ozone$InvTmp), col = "Red")

plot(ozone$Ozone~ozone$Wind, xlab='Ozone', ylab='Wind', main = "Ozone over Wind", col=c("green","blue"))
abline(lm(ozone$Ozone~ozone$Wind), col = "Red")
# Out:
# Plot with title “Ozone over Wind”

# %%
library(ggplot2); suppressWarnings(suppressMessages(library("ggplot2")))
options(repr.plot.width=3, repr.plot.height=3)
par(mfrow=c(2,2))

# Histogram with density plot
ggplot(ozone, aes(x=Ozone)) + 
 geom_histogram(aes(y=..density..), colour="black", fill="white")+
 geom_density(alpha=.3, fill="#FF6666") + scale_color_grey()+ scale_fill_grey() +
  theme_classic() + labs(x = "Ozone", title = "Histogram for Ozone") + theme_minimal()

# Histogram with density plot
ggplot(ozone, aes(x=Temp)) + 
 geom_histogram(aes(y=..density..), colour="black", fill="white")+
 geom_density(alpha=.3, fill="#FF6666") + scale_color_grey()+ scale_fill_grey() +
  theme_classic() + labs(x = "Temp", title = "Histogram for Temp") + theme_minimal()

# Histogram with density plot
ggplot(ozone, aes(x=InvHt)) + 
 geom_histogram(aes(y=..density..), colour="black", fill="white")+
 geom_density(alpha=.3, fill="#FF6666") + scale_color_grey()+ scale_fill_grey() +
  theme_classic() + labs(x = "InvHt", title = "Histogram for InvHt") + theme_minimal()

# Histogram with density plot
ggplot(ozone, aes(x=Pres)) + 
 geom_histogram(aes(y=..density..), colour="black", fill="white")+
 geom_density(alpha=.3, fill="#FF6666") + scale_color_grey()+ scale_fill_grey() +
  theme_classic() + labs(x = "Pres", title = "Histogram for Pres") + theme_minimal()

# Histogram with density plot
ggplot(ozone, aes(x=Vis)) + 
 geom_histogram(aes(y=..density..), colour="black", fill="white")+
 geom_density(alpha=.3, fill="#FF6666") + scale_color_grey()+ scale_fill_grey() +
  theme_classic() + labs(x = "Vis", title = "Histogram for Vis") + theme_minimal()

# Histogram with density plot
ggplot(ozone, aes(x=Hgt)) + 
 geom_histogram(aes(y=..density..), colour="black", fill="white")+
 geom_density(alpha=.3, fill="#FF6666") + scale_color_grey()+ scale_fill_grey() +
  theme_classic() + labs(x = "Hgt", title = "Histogram for Hgt") + theme_minimal()

# Histogram with density plot
ggplot(ozone, aes(x=Hum)) + 
 geom_histogram(aes(y=..density..), colour="black", fill="white")+
 geom_density(alpha=.3, fill="#FF6666") + scale_color_grey()+ scale_fill_grey() +
  theme_classic() + labs(x = "Hum", title = "Histogram for Hum") + theme_minimal()

# Histogram with density plot
ggplot(ozone, aes(x=InvTmp)) + 
 geom_histogram(aes(y=..density..), colour="black", fill="white")+
 geom_density(alpha=.3, fill="#FF6666") + scale_color_grey()+ scale_fill_grey() +
  theme_classic() + labs(x = "InvTmp", title = "Histogram for InvTmp") + theme_minimal()

# Histogram with density plot
ggplot(ozone, aes(x=Wind)) + 
 geom_histogram(aes(y=..density..), colour="black", fill="white")+
 geom_density(alpha=.3, fill="#FF6666") + scale_color_grey()+ scale_fill_grey() +
  theme_classic() + labs(x = "Wind", title = "Histogram for Wind") + theme_minimal()
# Out:
# Registered S3 methods overwritten by 'ggplot2':
#   method         from
#   [.quosures     rlang
#   c.quosures     rlang
#   print.quosures rlang
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title
# plot without title

# %%
## 2,3.
options(repr.plot.width=10, repr.plot.height=10)
fit2 <- glm(1/(Ozone)~., data=ozone)
summary(fit2)

par(mfrow=c(2,2))
plot(fit2)
# Out:
# Call:
# glm(formula = 1/(Ozone) ~ ., data = ozone)
#
# Deviance Residuals:
#      Min        1Q    Median        3Q       Max
# -0.20409  -0.04966  -0.01064   0.02971   0.73726
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  4.152e-01  5.931e-01   0.700    0.484
# Temp        -5.359e-03  1.041e-03  -5.150 4.56e-07 ***
# InvHt        2.789e-05  5.898e-06   4.730 3.37e-06 ***
# Pres        -1.532e-04  2.334e-04  -0.657    0.512
# Vis          1.088e-04  7.775e-05   1.399    0.163
# Hgt         -3.089e-05  1.123e-04  -0.275    0.783
# Hum          2.204e-04  3.882e-04   0.568    0.571
# InvTmp       2.479e-03  1.574e-03   1.575    0.116
# Wind        -1.512e-03  2.740e-03  -0.552    0.582
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for gaussian family taken to be 0.008613591)
#
#     Null deviance: 5.2513  on 329  degrees of freedom
# Residual deviance: 2.7650  on 321  degrees of freedom
# AIC: -621.58
#
# Number of Fisher Scoring iterations: 2
# Plot with title “”

# %%
options(digits = 3)
# drop1(fit2, test = "F")
fit_2_0 <- update(fit2,~. -Hum)

# drop1(fit_2_0, test = "F")
fit_2_1 <- update(fit_2_0,~. -Pres)

# drop1(fit_2_1, test = "F")
fit_2_2 <- update(fit_2_1,~. -Hgt)

# drop1(fit_2_2, test = "F")
fit_2_3 <- update(fit_2_2,~. -Wind)

# drop1(fit_2_3, test = "F")
fit_2_4 <- update(fit_2_3,~. -Vis)

summary(fit_2_4)
options(repr.plot.width=10, repr.plot.height=10)
par(mfrow=c(2,2))
plot(fit_2_4)
# Out:
# Call:
# glm(formula = 1/(Ozone) ~ Temp + InvHt + InvTmp, data = ozone)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -0.2144  -0.0495  -0.0093   0.0310   0.7410
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  2.70e-01   4.78e-02    5.64  3.7e-08 ***
# Temp        -5.86e-03   7.82e-04   -7.49  6.4e-13 ***
# InvHt        2.87e-05   5.00e-06    5.75  2.1e-08 ***
# InvTmp       2.69e-03   1.10e-03    2.44    0.015 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for gaussian family taken to be 0.00855)
#
#     Null deviance: 5.2513  on 329  degrees of freedom
# Residual deviance: 2.7882  on 326  degrees of freedom
# AIC: -628.8
#
# Number of Fisher Scoring iterations: 2
# Plot with title “”

# %%
options(repr.plot.width=10, repr.plot.height=10)
par(mfrow=c(3,3))

Rd2 = residuals(fit2,type='deviance')
plot(ozone$Ozone,Rd2, xlab='Ozone', ylab='Deviance residuals')
abline(0,0, col = "Red")

plot(ozone$Temp,Rd2, xlab='Temp', ylab='Deviance residuals')
abline(0,0, col = "Red")

plot(ozone$InvHt,Rd2, xlab='InvHt', ylab='Deviance residuals') 
abline(0,0, col = "Red")

plot(ozone$Pres,Rd2, xlab='Pres', ylab='Deviance residuals')
abline(0,0, col = "Red")

plot(ozone$Vis,Rd2, xlab='Vis', ylab='Deviance residuals')
abline(0,0, col = "Red")

plot(ozone$Hgt,Rd2, xlab='Hgt', ylab='Deviance residuals') 
abline(0,0, col = "Red")

plot(ozone$Hum,Rd2, xlab='Hum', ylab='Deviance residuals')
abline(0,0, col = "Red")

plot(ozone$InvTmp,Rd2, xlab='InvTmp', ylab='Deviance residuals')
abline(0,0, col = "Red")

plot(ozone$Wind,Rd2, xlab='wind', ylab='Deviance residuals')
abline(0,0, col = "Red")
# Out:
# plot without title

# %%
## 4.
fit3 = glm(Ozone~., data=ozone, family = Gamma(link = "inverse"))
fit4 = glm(Ozone~., data=ozone, family = gaussian(link = "log"))
# Although both models seem to have similar ammounts of significance it would seem that fit3 using the
# Gamma(link = "inverse") has less Resid. Dev than fit 3 and it would the better choice.
summary(fit3)
par(mfrow=c(2,2))
plot(fit3)
# Out:
# Call:
# glm(formula = Ozone ~ ., family = Gamma(link = "inverse"), data = ozone)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -1.4040  -0.3333  -0.0438   0.2309   1.1001
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  3.46e-01   2.64e-01    1.31   0.1907
# Temp        -1.26e-03   4.15e-04   -3.03   0.0027 **
# InvHt        1.25e-05   2.28e-06    5.47  9.0e-08 ***
# Pres        -2.28e-04   9.17e-05   -2.49   0.0134 *
# Vis          5.23e-05   3.32e-05    1.57   0.1166
# Hgt         -2.11e-05   4.91e-05   -0.43   0.6676
# Hum         -6.57e-04   1.47e-04   -4.47  1.1e-05 ***
# InvTmp      -5.32e-04   5.56e-04   -0.96   0.3394
# Wind         6.14e-04   9.76e-04    0.63   0.5295
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Gamma family taken to be 0.165)
#
#     Null deviance: 167.030  on 329  degrees of freedom
# Residual deviance:  57.541  on 321  degrees of freedom
# AIC: 1850
#
# Number of Fisher Scoring iterations: 5
# Plot with title “”

# %%
# drop1(fit3, test = "F")
fit_3_0 <- update(fit3,~. -Hgt)

# drop1(fit_3_0, test = "F")
fit_3_1 <- update(fit_3_0,~. -Wind)

# drop1(fit_3_1, test = "F")
fit_3_2 <- update(fit_3_1,~. -InvTmp)

# drop1(fit_3_2, test = "F")
fit_3_3 <- update(fit_3_2,~. -Vis)

# drop1(fit_3_3, test = "F")
fit_3_4 <- update(fit_3_3,~. -Pres)

summary(fit_3_4)
options(repr.plot.width=10, repr.plot.height=10)
par(mfrow=c(2,2))
plot(fit_3_4)
# Out:
# Call:
# glm(formula = Ozone ~ Temp + InvHt + Hum, family = gaussian(link = "log"),
#     data = ozone)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -12.994   -2.414   -0.195    2.079   14.295
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  4.68e-01   1.42e-01    3.31    0.001 **
# Temp         2.57e-02   1.60e-03   16.03  < 2e-16 ***
# InvHt       -1.20e-04   1.62e-05   -7.37  1.5e-12 ***
# Hum          9.40e-03   1.29e-03    7.32  2.0e-12 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for gaussian family taken to be 17)
#
#     Null deviance: 21115.4  on 329  degrees of freedom
# Residual deviance:  5556.7  on 326  degrees of freedom
# AIC: 1878
#
# Number of Fisher Scoring iterations: 5
# Plot with title “”

# %%
# Goodness of fit test inv Gamma
(pval <- 1 - pchisq(57.541, 321))

# Goodness of fit test log Gaussian
(pval <- 1 - pchisq(5405.5, 321))
# Out:
# [1] 1
# [1] 0

# %%
## 5.
anova(fit2, fit, test="Chisq") # anova can not be used as fit2 has its dependent Ozone variable transformed by inverse.
summary(fit2)
summary(fit3)
# Comparing the model from question 3 and question 4, I would definitly choose question 4 model as it provides higher
# significance on more variables.
# Out:
# Warning message in anova.glmlist(c(list(object), dotargs), dispersion = dispersion, :
# “models with response ‘"Ozone"’ removed because response differs from model 1”
#        Df Deviance                 Resid. Df Resid. Dev
# NULL   NA                       NA 329       5.2512707808846359470
# Temp    1 2.1162540826600193533125 328       3.1350166982246165936
# InvHt   1 0.2957542381263613684439 327       2.8392624600982552252
# Pres    1 0.0357286425838374555042 326       2.8035338175144177697
# Vis     1 0.0101697365558903740634 325       2.7933640809585273956
# Hgt     1 0.0023465586214759248662 324       2.7910175223370514708
# Hum     1 0.0033287847971656958634 323       2.7876887375398857749
# InvTmp  1 0.0201045509485187068321 322       2.7675841865913670681
# Wind    1 0.0026215455897005135455 321       2.7649626410016665545
#        Pr(>Chi)
# NULL                          NA
# Temp   2.2624163019591270994e-55
# InvHt  4.6377988615403485839e-09
# Pres   4.1685251091588666761e-02
# Vis    2.7722133200928344987e-01
# Hgt    6.0170959201221296819e-01
# Hum    5.3416751315789068322e-01
# InvTmp 1.2657219298133631780e-01
# Wind   5.8116818086344768091e-01
# Call:
# glm(formula = 1/(Ozone) ~ ., data = ozone)
#
# Deviance Residuals:
#                   Min                     1Q                 Median
# -0.204087331050153059  -0.049655568858173176  -0.010637054568465462
#                    3Q                    Max
#  0.029710984016360058   0.737257627351052935
#
# Coefficients:
#                            Estimate              Std. Error
# (Intercept)  4.1517119918132256e-01  5.9309960625087532e-01
# Temp        -5.3586551482524957e-03  1.0405884657672016e-03
# InvHt        2.7893432211879072e-05  5.8975225633976494e-06
# Pres        -1.5323954651746643e-04  2.3339102034774010e-04
# Vis          1.0877194971240238e-04  7.7746075004993018e-05
# Hgt         -3.0893539482555095e-05  1.1233999933355056e-04
# Hum          2.2035925236059834e-04  3.8824575398691452e-04
# InvTmp       2.4790867344807442e-03  1.5740165244593825e-03
# Wind        -1.5115164351692085e-03  2.7398468275425360e-03
#                          t value   Pr(>|t|)
# (Intercept)  0.69999999999999996    0.48443
# Temp        -5.14963999999999977 4.5616e-07 ***
# InvHt        4.72968999999999973 3.3736e-06 ***
# Pres        -0.65658000000000005    0.51192
# Vis          1.39907000000000004    0.16276
# Hgt         -0.27500000000000002    0.78349
# Hum          0.56757999999999997    0.57072
# InvTmp       1.57501000000000002    0.11624
# Wind        -0.55167999999999995    0.58155
# ---
# Signif. codes:
#   0 ‘***’ 0.0010000000000000000208 ‘**’ 0.010000000000000000208 ‘*’
#   0.050000000000000002776 ‘.’ 0.10000000000000000555 ‘ ’ 1
#
# (Dispersion parameter for gaussian family taken to be 0.0086135907819366551441)
#
#     Null deviance: 5.25127078088463595  on 329  degrees of freedom
# Residual deviance: 2.76496264100166655  on 321  degrees of freedom
# AIC: -621.582193304788234
#
# Number of Fisher Scoring iterations: 2
# Call:
# glm(formula = Ozone ~ ., family = Gamma(link = "inverse"), data = ozone)
#
# Deviance Residuals:
#                   Min                     1Q                 Median
# -1.404008037467064263  -0.333307074512999846  -0.043814759734269487
#                    3Q                    Max
#  0.230908899825216979   1.100053920334461033
#
# Coefficients:
#                            Estimate              Std. Error
# (Intercept)  3.4647448643369633e-01  2.6423926984330931e-01
# Temp        -1.2563029061960595e-03  4.1477380546391281e-04
# InvHt        1.2461009578589029e-05  2.2773092089308135e-06
# Pres        -2.2820518427779261e-04  9.1734072732675351e-05
# Vis          5.2287009526032811e-05  3.3232783909883922e-05
# Hgt         -2.1087715505452291e-05  4.9066234814217557e-05
# Hum         -6.5739550455507759e-04  1.4695059106513899e-04
# InvTmp      -5.3174550287167814e-04  5.5573559454503475e-04
# Wind         6.1418150063157048e-04  9.7577607682127789e-04
#                          t value   Pr(>|t|)
# (Intercept)  1.31120999999999999  0.1907223
# Temp        -3.02889000000000008  0.0026537 **
# InvHt        5.47180999999999962 8.9843e-08 ***
# Pres        -2.48768000000000011  0.0133650 *
# Vis          1.57336000000000009  0.1166214
# Hgt         -0.42978000000000000  0.6676436
# Hum         -4.47358000000000011 1.0691e-05 ***
# InvTmp      -0.95682999999999996  0.3393722
# Wind         0.62943000000000005  0.5295161
# ---
# Signif. codes:
#   0 ‘***’ 0.0010000000000000000208 ‘**’ 0.010000000000000000208 ‘*’
#   0.050000000000000002776 ‘.’ 0.10000000000000000555 ‘ ’ 1
#
# (Dispersion parameter for Gamma family taken to be 0.16525512651339088754)
#
#     Null deviance: 167.030224393548963  on 329  degrees of freedom
# Residual deviance:  57.540866906921103  on 321  degrees of freedom
# AIC: 1850.26099324357688
#
# Number of Fisher Scoring iterations: 5

# %%
# Goodness of fit Exercise 3
(pval <- 1 - pchisq(2.7650, 321))

# Goodness of fit Exercise 4
(pval <- 1 - pchisq(57.541, 321))
# Out:
# [1] 1
# [1] 1

# %%
## 6.

# According to p. 106 in the book, Theorem 4.2:
# Sigma = [X'W(beta)X]^-1
# Where X is the model matrix and W(beta) = diag(wi/g'(mui)^2*V(mui))
# wi is the estimated shape parameter of the Gamma distribution (which is our current models case)
# alpha is the the dispertion paramter estimated in the given fit. Taking the diagonal of alpha mulitplied by 
# the the estimated target values squared will give W(beta). 

X = model.matrix(fit3)
alpha = 1/summary(fit3)$dispersion # dispersion value
W = diag(alpha * fit3$fitted.values^2) # This is for the inverse link-function
#W = w/((g_prime_mu**2)*V_mu)

disp_mat = solve(t(X) %*% W %*% X)
summary(fit3)$cov.scaled
all.equal(disp_mat, summary(fit3)$cov.scaled, tolerance=1e-4) # Outputs: TRUE
# Out:
#             (Intercept)   Temp          InvHt         Pres
# (Intercept)  6.982239e-02  3.785029e-05  7.008260e-08 -1.751906e-06
# Temp         3.785029e-05  1.720373e-07 -2.841320e-10 -2.337357e-08
# InvHt        7.008260e-08 -2.841320e-10  5.186137e-12  3.413368e-11
# Pres        -1.751906e-06 -2.337357e-08  3.413368e-11  8.415140e-09
# Vis         -1.824082e-06 -1.062261e-09 -2.737690e-12 -2.703385e-10
# Hgt         -1.291934e-05 -6.469145e-09 -1.920439e-11  2.715483e-10
# Hum         -3.531587e-06  2.517632e-09 -3.239176e-12 -4.929188e-09
# InvTmp       4.231373e-05 -1.629929e-07  7.723178e-10  2.796190e-08
# Wind        -2.811397e-05 -5.813844e-08 -1.973476e-10 -3.969395e-09
#             Vis           Hgt           Hum           InvTmp
# (Intercept) -1.824082e-06 -1.291934e-05 -3.531587e-06  4.231373e-05
# Temp        -1.062261e-09 -6.469145e-09  2.517632e-09 -1.629929e-07
# InvHt       -2.737690e-12 -1.920439e-11 -3.239176e-12  7.723178e-10
# Pres        -2.703385e-10  2.715483e-10 -4.929188e-09  2.796190e-08
# Vis          1.104418e-09  2.760260e-10  1.902023e-09  1.127894e-09
# Hgt          2.760260e-10  2.407495e-09  4.329879e-10 -9.272479e-09
# Hum          1.902023e-09  4.329879e-10  2.159448e-08 -8.908942e-09
# InvTmp       1.127894e-09 -9.272479e-09 -8.908942e-09  3.088421e-07
# Wind         3.750497e-10  4.660883e-09 -7.150572e-09  2.098136e-08
#             Wind
# (Intercept) -2.811397e-05
# Temp        -5.813844e-08
# InvHt       -1.973476e-10
# Pres        -3.969395e-09
# Vis          3.750497e-10
# Hgt          4.660883e-09
# Hum         -7.150572e-09
# InvTmp       2.098136e-08
# Wind         9.521390e-07
# [1] TRUE

# %%
## 2.1, 2.2
model1 = glm(Ozone~Temp, data=ozone, family=Gamma(link = "inverse"))
summary(model1)
model2 = glm(Ozone~Temp+Hum, data=ozone, family=Gamma(link = "inverse"))
anova(model1, model2, test="Chisq")
model3 = glm(Ozone~Temp+Hum+InvHt, data=ozone, family=Gamma(link = "inverse"))
anova(model2, model3, test="Chisq")
model4 = glm(Ozone~Temp+Hum+InvHt+Vis, data=ozone, family=Gamma(link = "inverse"))
anova(model3, model4, test="Chisq") # Shows that model4 is not significantly better than model3
model5 = glm(Ozone~Temp+Hum+InvHt+Wind, data=ozone, family=Gamma(link = "inverse"))
anova(model3, model5, test="Chisq") # Shows that model5 is not significantly better than model3
model6 = glm(Ozone~ Temp+I(Temp*Temp)+Hum+InvHt, data=ozone, family=Gamma(link = "inverse"))
anova(model3, model6, test="Chisq")
model7 = glm(Ozone~ Temp+I(Temp*Temp)+Hum+InvHt*Temp, data=ozone, family=Gamma(link = "inverse"))
anova(model6, model7, test="Chisq")
model8 = glm(Ozone~ Temp+I(Temp*Temp)+InvHt*Temp, data=ozone, family=Gamma(link = "inverse"))
anova(model7, model8, test="Chisq") 
summary(model8) # This seems to be a good fit
anova(model1, model8, test="Chisq")

# Residuals plots look fine, independent, randomly distributed and not skewed. 
plot(model8) 
hist(model8$residuals, breaks=50, probability=TRUE)
lines(density(model8$residuals), # density plot
      lwd=2, # thickness of line
      col="chocolate3")

# Using drop1 to find best fit model
model1_ = glm(Ozone~ Temp*InvHt*Pres*Vis*Hgt*Hum*InvTmp*Wind, data=ozone, family=Gamma(link = "inverse")) # Most complex model possible

# This function uses for and if loops, given R is bad with memory it takes time for more complex models ...
drop_func = function(fit, alpha=0.1){
  delta = c()
  for(i in 1:length(coef(fit))) {
    drp = drop1(fit, test="Chisq")
    if(drp$`Pr(>Chi)`[which.max(drp$`Pr(>Chi)`)] >= alpha){
      delta = c(delta, paste0(" -", row.names(drp)[which.max(drp$`Pr(>Chi)`)]))
      fit = update(fit, paste("~ .", paste(delta, collapse=" ")))
    } else{
      return(fit)
    }
  }
}
m = drop_func(model1_, alpha=0.01)
summary(m)
m2 = drop_func(model1_, alpha=0.001) # Try with higher significance
summary(m2) # InvTmp is not significant
m2_ = update(m2, .~. -InvTmp)
summary(m2_)
anova(model8, m, test="Chisq") 
anova(m, m2, test="Chisq")  # m2 looks to be the best model we can produce using drop1
anova(m2, m2_, test="Chisq") # Not significantly better without InvTmp. 

plot(m2) 
hist(m2$residuals, breaks=50, probability=TRUE, main="Histogram plot of residuals", xlab="Residuals", ylab="Density")
lines(density(m2$residuals), # density plot
      lwd=2, # thickness of line
      col="chocolate3")
# Out:
# Call:
# glm(formula = Ozone ~ Temp, family = Gamma(link = "inverse"),
#     data = ozone)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -1.4424  -0.4438  -0.0777   0.2492   1.3536
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.281487   0.010766   26.15   <2e-16 ***
# Temp        -0.002832   0.000135  -20.98   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Gamma family taken to be 0.2287771)
#
#     Null deviance: 167.030  on 329  degrees of freedom
# Residual deviance:  78.818  on 328  degrees of freedom
# AIC: 1943.6
#
# Number of Fisher Scoring iterations: 5
#   Resid. Df Resid. Dev Df Deviance Pr(>Chi)
# 1 328       78.81812   NA       NA           NA
# 2 327       70.11376    1 8.704364 6.158123e-11
#   Resid. Df Resid. Dev Df Deviance Pr(>Chi)
# 1 327       70.11376   NA       NA           NA
# 2 326       58.95218    1 11.16158 3.871136e-16
#   Resid. Df Resid. Dev Df Deviance  Pr(>Chi)
# 1 326       58.95218   NA        NA        NA
# 2 325       58.62558    1 0.3265933 0.1613068
#   Resid. Df Resid. Dev Df Deviance   Pr(>Chi)
# 1 326       58.95218   NA         NA        NA
# 2 325       58.90441    1 0.04776204 0.5945377
#   Resid. Df Resid. Dev Df Deviance Pr(>Chi)
# 1 326       58.95218   NA       NA           NA
# 2 325       52.43517    1 6.517003 9.531403e-11
#   Resid. Df Resid. Dev Df Deviance Pr(>Chi)
# 1 325       52.43517   NA       NA          NA
# 2 324       50.85147    1 1.583706 0.001163285
#   Resid. Df Resid. Dev Df Deviance  Pr(>Chi)
# 1 324       50.85147   NA        NA           NA
# 2 325       55.83880   -1 -4.987329 8.244764e-09
# Call:
# glm(formula = Ozone ~ Temp + I(Temp * Temp) + InvHt * Temp, family = Gamma(link = "inverse"),
#     data = ozone)
#
# Deviance Residuals:
#      Min        1Q    Median        3Q       Max
# -1.25181  -0.33733  -0.02713   0.23378   1.27169
#
# Coefficients:
#                  Estimate Std. Error t value Pr(>|t|)
# (Intercept)     3.843e-01  6.432e-02   5.975 6.03e-09 ***
# Temp           -7.774e-03  1.705e-03  -4.559 7.27e-06 ***
# I(Temp * Temp)  4.362e-05  1.112e-05   3.924 0.000106 ***
# InvHt           4.256e-05  8.982e-06   4.738 3.23e-06 ***
# Temp:InvHt     -4.802e-07  1.369e-07  -3.508 0.000516 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Gamma family taken to be 0.163088)
#
#     Null deviance: 167.030  on 329  degrees of freedom
# Residual deviance:  55.839  on 325  degrees of freedom
# AIC: 1832.1
#
# Number of Fisher Scoring iterations: 5
#   Resid. Df Resid. Dev Df Deviance Pr(>Chi)
# 1 328       78.81812   NA       NA           NA
# 2 325       55.83880    3 22.97932 2.416076e-30
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Call:
# glm(formula = Ozone ~ Temp + InvHt + Pres + Vis + Hgt + Hum +
#     InvTmp + Wind + Temp:Vis + InvHt:Vis + Temp:Hgt + InvHt:Hgt +
#     InvHt:Hum + Pres:Hum + Hgt:Hum + Temp:InvTmp + InvHt:InvTmp +
#     Vis:InvTmp + Hgt:InvTmp + Hum:InvTmp + Temp:Wind + InvHt:Wind +
#     Vis:Wind + InvTmp:Wind + InvHt:Hgt:Hum + Temp:Vis:InvTmp +
#     InvHt:Vis:InvTmp + Hgt:Hum:InvTmp + Temp:Vis:Wind + InvHt:Vis:Wind +
#     Temp:InvTmp:Wind + InvHt:InvTmp:Wind + Vis:InvTmp:Wind +
#     Temp:Vis:InvTmp:Wind + InvHt:Vis:InvTmp:Wind, family = Gamma(link = "inverse"),
#     data = ozone)
#
# Deviance Residuals:
#      Min        1Q    Median        3Q       Max
# -1.22839  -0.25542  -0.03925   0.17848   1.11350
#
# Coefficients:
#                         Estimate Std. Error t value Pr(>|t|)
# (Intercept)           -1.928e+01  5.432e+00  -3.550 0.000448 ***
# Temp                  -8.459e-02  2.805e-02  -3.016 0.002788 **
# InvHt                  1.495e-03  5.607e-04   2.667 0.008070 **
# Pres                  -1.274e-03  2.925e-04  -4.354 1.85e-05 ***
# Vis                   -6.953e-03  3.562e-03  -1.952 0.051920 .
# Hgt                    3.502e-03  9.418e-04   3.718 0.000240 ***
# Hum                    4.086e-01  9.180e-02   4.451 1.22e-05 ***
# InvTmp                 2.782e-01  7.383e-02   3.768 0.000199 ***
# Wind                  -2.273e-01  9.134e-02  -2.488 0.013398 *
# Temp:Vis               6.334e-05  4.432e-05   1.429 0.154057
# InvHt:Vis              9.409e-07  4.682e-07   2.009 0.045403 *
# Temp:Hgt               1.329e-05  4.859e-06   2.735 0.006617 **
# InvHt:Hgt             -2.687e-07  9.761e-08  -2.753 0.006281 **
# InvHt:Hum             -3.229e-05  9.114e-06  -3.543 0.000461 ***
# Pres:Hum               1.754e-05  4.331e-06   4.051 6.53e-05 ***
# Hgt:Hum               -7.118e-05  1.588e-05  -4.481 1.06e-05 ***
# Temp:InvTmp            9.644e-05  7.435e-05   1.297 0.195623
# InvHt:InvTmp           1.042e-06  1.012e-06   1.029 0.304218
# Vis:InvTmp             1.246e-04  5.608e-05   2.221 0.027100 *
# Hgt:InvTmp            -5.013e-05  1.267e-05  -3.958 9.50e-05 ***
# Hum:InvTmp            -4.490e-03  1.131e-03  -3.970 9.04e-05 ***
# Temp:Wind              2.681e-03  1.174e-03   2.283 0.023131 *
# InvHt:Wind             3.459e-05  1.152e-05   3.002 0.002909 **
# Vis:Wind               2.004e-03  6.791e-04   2.951 0.003427 **
# InvTmp:Wind            3.376e-03  1.315e-03   2.568 0.010735 *
# InvHt:Hgt:Hum          5.619e-09  1.574e-09   3.570 0.000417 ***
# Temp:Vis:InvTmp       -1.173e-06  6.227e-07  -1.883 0.060655 .
# InvHt:Vis:InvTmp      -1.653e-08  8.024e-09  -2.060 0.040242 *
# Hgt:Hum:InvTmp         7.816e-07  1.945e-07   4.019 7.44e-05 ***
# Temp:Vis:Wind         -2.188e-05  8.663e-06  -2.526 0.012078 *
# InvHt:Vis:Wind        -2.724e-07  9.092e-08  -2.996 0.002968 **
# Temp:InvTmp:Wind      -3.790e-05  1.532e-05  -2.473 0.013964 *
# InvHt:InvTmp:Wind     -6.026e-07  1.918e-07  -3.141 0.001854 **
# Vis:InvTmp:Wind       -3.316e-05  1.074e-05  -3.089 0.002203 **
# Temp:Vis:InvTmp:Wind   3.527e-07  1.187e-07   2.972 0.003204 **
# InvHt:Vis:InvTmp:Wind  4.845e-09  1.563e-09   3.101 0.002119 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Gamma family taken to be 0.1296145)
#
#     Null deviance: 167.030  on 329  degrees of freedom
# Residual deviance:  39.272  on 294  degrees of freedom
# AIC: 1775.2
#
# Number of Fisher Scoring iterations: 5
# Call:
# glm(formula = Ozone ~ Temp + InvHt + Pres + Hum + InvTmp + Pres:Hum +
#     InvHt:InvTmp, family = Gamma(link = "inverse"), data = ozone)
#
# Deviance Residuals:
#      Min        1Q    Median        3Q       Max
# -1.26388  -0.27784  -0.04201   0.21609   0.99654
#
# Coefficients:
#                Estimate Std. Error t value Pr(>|t|)
# (Intercept)   1.841e-01  2.068e-02   8.904  < 2e-16 ***
# Temp         -1.195e-03  3.558e-04  -3.358 0.000881 ***
# InvHt         5.791e-05  6.859e-06   8.443 1.07e-15 ***
# Pres         -1.414e-03  2.623e-04  -5.392 1.35e-07 ***
# Hum          -6.687e-04  1.240e-04  -5.393 1.35e-07 ***
# InvTmp        1.266e-04  4.973e-04   0.255 0.799154
# Pres:Hum      2.053e-05  3.954e-06   5.192 3.69e-07 ***
# InvHt:InvTmp -8.200e-07  1.110e-07  -7.387 1.30e-12 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Gamma family taken to be 0.1379324)
#
#     Null deviance: 167.030  on 329  degrees of freedom
# Residual deviance:  48.395  on 322  degrees of freedom
# AIC: 1789.6
#
# Number of Fisher Scoring iterations: 5
# Call:
# glm(formula = Ozone ~ Temp + InvHt + Pres + Hum + Pres:Hum +
#     InvHt:InvTmp, family = Gamma(link = "inverse"), data = ozone)
#
# Deviance Residuals:
#      Min        1Q    Median        3Q       Max
# -1.27067  -0.27674  -0.04356   0.21484   0.98893
#
# Coefficients:
#                Estimate Std. Error t value Pr(>|t|)
# (Intercept)   1.879e-01  1.456e-02  12.907  < 2e-16 ***
# Temp         -1.115e-03  1.683e-04  -6.624 1.46e-10 ***
# InvHt         5.712e-05  6.108e-06   9.352  < 2e-16 ***
# Pres         -1.427e-03  2.570e-04  -5.550 5.95e-08 ***
# Hum          -6.660e-04  1.230e-04  -5.414 1.21e-07 ***
# Pres:Hum      2.052e-05  3.943e-06   5.205 3.45e-07 ***
# InvHt:InvTmp -8.119e-07  1.059e-07  -7.669 2.05e-13 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Gamma family taken to be 0.1372887)
#
#     Null deviance: 167.030  on 329  degrees of freedom
# Residual deviance:  48.403  on 323  degrees of freedom
# AIC: 1787.7
#
# Number of Fisher Scoring iterations: 5
#   Resid. Df Resid. Dev Df Deviance Pr(>Chi)
# 1 325       55.83880   NA       NA          NA
# 2 294       39.27164   31 16.56716 1.02251e-13
#   Resid. Df Resid. Dev Df  Deviance  Pr(>Chi)
# 1 294       39.27164    NA        NA           NA
# 2 322       48.39454   -28 -9.122903 1.643946e-05
#   Resid. Df Resid. Dev Df Deviance     Pr(>Chi)
# 1 322       48.39454   NA           NA        NA
# 2 323       48.40349   -1 -0.008953698 0.7988918
# Plot with title “Histogram of model8$residuals”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “Histogram plot of residuals”
